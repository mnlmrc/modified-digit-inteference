# %%
import pandas as pd

data = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-02/behav_sub-02.tsv',sep='\t')
data2 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-03/behav_sub-03.tsv',sep='\t')
data3 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-04/behav_sub-04.tsv',sep='\t')
data5 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-06/behav_sub-06.tsv',sep='\t')
data6 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-07/behav_sub-07.tsv',sep='\t')
data8 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-09/behav_sub-09.tsv',sep='\t')
data9 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-10/behav_sub-10.tsv',sep='\t')
data10 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-11/behav_sub-11.tsv',sep='\t')
data11 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-12/behav_sub-12.tsv',sep='\t')
data12 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-13/behav_sub-13.tsv',sep='\t')
data13 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-14/behav_sub-14.tsv',sep='\t')
data14 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-15/behav_sub-15.tsv',sep='\t')
data15 = pd.read_csv('/cifs/diedrichsen/data/Articulation/Sequence1/behavioral/manual/sub-16/behav_sub-16.tsv',sep='\t')

# %%
data.head()
# Out:
#   trial_num condition                           stimulus start_time go_signal  \
# 0         1    random  da pre tor ti nent con de mo crat          4         3
# 1         2    simple                                pre         12         3
# 2         3    simple                                 de         20         3
# 3         4    simple                                 ti         28         3
# 4         5      word  con ti nent de mo crat pre da tor         36         3
#
#   resp_time record_time run trial start_time_real end_time_real
# 0         4         4.5   1     1       4.0000149    11.0029763
# 1         4         4.5   1     2       12.000016    19.0029149
# 2         4         4.5   1     3      20.0000233    27.0038793
# 3         4         4.5   1     4      28.0000423    35.0026908
# 4         4         4.5   1     5      36.0000162     43.002779

# %%
(data["run"][478] == data["run"][479]) & (data["stimulus"][478] == data["stimulus"][479])
# Out:
# True

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# 16

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data2["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# 3

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data3["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# 0

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data5["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# 3

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data6["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# 5

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data8["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# 0

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data9["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# 5

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data10["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# 1

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data11["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/indexes/range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: 257 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 5
#       2 i = 0
#       4 while i < len(data["stimulus"]) - 1:
# ----> 5     if (data11["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
#       6         count += 1
#       7     i += 1
#
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
# ...

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data12["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/indexes/range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: 257 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 5
#       2 i = 0
#       4 while i < len(data["stimulus"]) - 1:
# ----> 5     if (data12["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
#       6         count += 1
#       7     i += 1
#
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
# ...

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data13["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/indexes/range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: 268 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 5
#       2 i = 0
#       4 while i < len(data["stimulus"]) - 1:
# ----> 5     if (data13["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
#       6         count += 1
#       7     i += 1
#
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
# ...

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data14["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/indexes/range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: 268 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 5
#       2 i = 0
#       4 while i < len(data["stimulus"]) - 1:
# ----> 5     if (data14["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
#       6         count += 1
#       7     i += 1
#
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
# ...

# %%
count = 0
i = 0

while i < len(data["stimulus"]) - 1:
    if (data15["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
        count += 1
    i += 1


print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/indexes/range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: 257 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 5
#       2 i = 0
#       4 while i < len(data["stimulus"]) - 1:
# ----> 5     if (data15["stimulus"][i] == data["stimulus"][i+1]) & (data["run"][i] == data["run"][i+1]):
#       6         count += 1
#       7     i += 1
#
# File ~/Documents/GitHub/modified-digit-inteference/.venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
# ...
